# %% [markdown]
# # Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
df1 = pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist',bins=20)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar(stacked=True)

# %%
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.plot.line(y = 'B',figsize=(12,3),lw=3)

# %%
df1.plot.scatter(x ='A', y= 'B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x ='A', y= 'B',s = df1['C']*100,c='C',cmap='coolwarm')
# Out:
# /home/sudhir/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['a','b'])
df.plot.hexbin(x = 'a', y = 'b',gridsize=25,cmap='coolwarm')

# %%
df2.plot.kde()

# %% [markdown]
# ## Pandas Built-in Data Visualization Exercise Overview

# %%
df3 = pd.read_csv('df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot(x = 'a', y = 'b', kind = 'scatter',c='r',figsize=(12,3))

# %%
df3['a'].plot(kind='hist')

# %%
plt.style.use('ggplot')
df3['a'].plot(kind='hist', bins=50)

# %%
df3[['a','b']].plot.box()

# %%
df3['d'].plot(kind='kde')

# %%
df3.plot()

# %%
df3['d'].plot(kind='kde', lw=3,style='--')

# %%
df3.loc[:30].plot(kind='area')

# %% [markdown]
# #### Great Job
